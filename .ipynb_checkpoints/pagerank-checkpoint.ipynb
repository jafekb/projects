# %% [markdown]
# # PageRank Algorithm
# ## Here we implement a (very) simple version of Google's PageRank Algorithm

# %% [markdown]
# ### Import our libraries

# %%
from __future__ import division
import numpy as np
import scipy as sp
from scipy import sparse
import numpy.linalg as la

# %%
def to_matrix(filename, n):
    """Return the nxn adjacency matrix described by datafile.

    Parameters:
        datafile (str): The name of a .txt file describing a directed graph.
        Lines describing edges should have the form '<from node>\t<to node>\n'.
        The file may also include comments.
    n (int): The number of nodes in the graph described by datafile

    Returns:
        A SciPy sparse dok_matrix.
    """
    A = np.zeros((n,n))
    with open(filename, 'r') as myfile:
        for line in myfile:
            line = line.strip().split()
            try:
                A[int(line[0]),int(line[1])]=1
            except:
                continue
    return sparse.dok_matrix(A)

# %%
def calculateK(A,N):
    """Compute the matrix K as described in the lab.

    Parameters:
        A (ndarray): adjacency matrix of an array
        N (int): the datasize of the array

    Returns:
        K (ndarray)
    """
    if type(A) == sparse.dok_matrix:
        A = sparse.dok_matrix.toarray(A)
    #Fix A so that any rows of all zeros become all ones
    for i in xrange(len(A)):
        if np.all(A[i]==0):
            A[i]=1
            
    #Calculate D
    D = np.diag([A.sum(1)[i] for i in xrange(len(A))])
    #Return K
    return la.inv(D).dot(A).T

# %% [markdown]
# ### First we sort them using an iterative method

# %%
def iter_solve(adj, N=None, d=.85, tol=1E-5):
    """Return the page ranks of the network described by 'adj'.
    Iterate through the PageRank algorithm until the error is less than 'tol'.

    Parameters:
        adj (ndarray): The adjacency matrix of a directed graph.
        N (int): Restrict the computation to the first 'N' nodes of the graph.
            If N is None (default), use the entire matrix.
        d (float): The damping factor, a float between 0 and 1.
        tol (float): Stop iterating when the change in approximations to the
            solution is less than 'tol'.

    Returns:
        The approximation to the steady state.
    """
    if type(adj) == sparse.dok_matrix:
        adj = sparse.dok_matrix.toarray(adj)
    if N==None:
        N = len(adj)

    K = np.array(calculateK(adj[:N,:N], N))
    pold = np.random.random(N)
    pold /= la.norm(pold)
    pnew = np.ones(N)
    i=0
    while la.norm(pnew - pold) > tol:
        pnew, pold = d*K.dot(pold) + (1-d)/N * np.ones(N), pnew
        #Iteration count
        i+=1
        if i > 500:
            raise ValueError('Did not converge')
    return pnew

# %% [markdown]
# ### We can solve the same problem using eigenvalues

# %%
def eig_solve(adj, N=None, d=.85):
    """Return the page ranks of the network described by 'adj'. Use SciPy's
    eigenvalue solver to calculate the steady state of the PageRank algorithm

    Parameters:
        adj (ndarray): The adjacency matrix of a directed graph.
        N (int): Restrict the computation to the first 'N' nodes of the graph.
            If N is None (default), use the entire matrix.
        d (float): The damping factor, a float between 0 and 1.
        tol (float): Stop iterating when the change in approximations to the
            solution is less than 'tol'.

    Returns:
        The approximation to the steady state.
    """
    if type(adj) == sparse.dok_matrix:
        adj = sparse.dok_matrix.toarray(adj)
        
    if N==None:
        N = len(adj)

    K = calculateK(adj[:N,:N], N)
    E = np.ones((N,N))
    B = d*K + (1-d)/N * E

    eigvals = la.eig(B)[0]
    one_eigval = list(eigvals).index(max(eigvals))
    eigvecs = la.eig(B)[1]
    return np.real(eigvecs[:,one_eigval]/np.sum(eigvecs[:,one_eigval]))

# %% [markdown]
# ### Now we'll use our iterative solver to organize some data about NCAA basketball teams in 2013, to rank them in order from best to worst.

# %%
def team_rank(filename='Data/ncaa2013.csv'):
    """Use iter_solve() to predict the rankings of the teams in the given
    dataset of games. The dataset should have two columns, representing
    winning and losing teams. Each row represents a game, with the winner on
    the left, loser on the right. Parse this data to create the adjacency
    matrix, and feed this into the solver to predict the team ranks.

    Parameters:
        filename (str): The name of the data file.
    Returns:
        ranks (list): The ranks of the teams from best to worst.
        teams (list): The names of the teams, also from best to worst.
    """
    all_teams=[]
    matches=[]
    #Get the data
    with open(filename, 'r') as ncaafile:
        ncaafile.readline() #reads and ignores the header line
        for line in ncaafile:
            team = line.strip().split(',') #split on commas
            all_teams.append(team[0])
            all_teams.append(team[1])
            matches.append(team)

    #Get the number of teams
    unique_teams = list(set(all_teams))
    team_count = len(unique_teams)

    #Here we're going to use (1) unique team name indices and (2) the game information
    # that we have, in order to make that adjacency matrix.
    A = np.zeros((team_count, team_count))

    for i in xrange(len(matches)):
        n, m = unique_teams.index(matches[i][0]), unique_teams.index(matches[i][1])
        A[m, n] = 1

    N = len(A)
    A1 = sparse.dok_matrix(A)
    rankings = iter_solve(A1, d=.7)
    teams = np.vstack((rankings, unique_teams)).T
    
    ranked_teams = teams[teams[:,0].argsort()][:,1][::-1]
    rankings = teams[teams[:,0].argsort()][:,0][::-1]
    return ranked_teams, rankings

# %% [markdown]
# # The team_rank function in action

# %%
print team_rank()
# Out:
# (array(['Duke', 'Butler', 'Louisville', 'Illinois', 'Indiana', 'Miami FL',
#        'Syracuse', 'Ohio St', 'Michigan St', 'Kansas', 'Minnesota',
#        'Michigan', 'Georgetown', 'Wisconsin', 'St Louis', 'Virginia',
#        'New Mexico', 'Marquette', 'Notre Dame', 'NC State',
#        'VA Commonwealth', 'Oklahoma St', 'Florida', 'Villanova', 'Temple',
#        'Arizona', 'UNLV', 'Missouri', 'Cincinnati', 'Pittsburgh', 'Xavier',
#        'UCLA', 'Connecticut', 'Colorado', 'Gonzaga', 'Creighton', 'Oregon',
#        'San Diego St', 'California', 'Oklahoma', 'Wichita St', 'Maryland',
#        'La Salle', 'Tennessee', 'Colorado St', 'North Carolina',
#        'Kentucky', 'Indiana St', 'Mississippi', 'Boise St', 'Charlotte',
#        'Iowa St', 'Baylor', 'Kansas St', 'Arkansas', 'Texas A&M', 'Iowa',
#        'Georgia Tech', 'Air Force', 'Massachusetts', 'Florida St',
#        'Memphis', 'Washington', 'Arizona St', 'USC', 'Wake Forest', 'Utah',
#        'Alabama', "St John's", 'Northern Iowa', "St Mary's CA", 'Purdue',
#        'Stanford', 'Providence', 'Richmond', 'Belmont', 'Illinois St',
#        'Bucknell', 'Akron', 'Dayton', "St Joseph's PA", 'LSU', 'Nebraska',
#        'Evansville', 'Boston College', 'BYU', 'Murray St', 'South Florida',
#        'Northwestern', 'S Dakota St', 'Middle Tenn St', 'Texas',
#        'New Mexico St', 'Southern Miss', 'UTEP', 'Virginia Tech',
#        'Wyoming', 'Louisiana Tech', 'Penn St', 'Valparaiso', 'Pacific',
#        'Rutgers', 'Detroit', 'UCF', 'FL Gulf Coast', 'Drake',
#        'Santa Clara', 'TCU', 'Canisius', 'St Bonaventure', 'Oregon St',
#        'S Illinois', 'Denver', 'IL Chicago', 'Iona', 'Vanderbilt',
#        'Georgia', 'Loyola MD', 'Northeastern', 'Utah St', 'Robert Morris',
#        'Albany NY', 'Seton Hall', 'Col Charleston', 'Nevada', 'Kent',
#        'Vermont', 'Bryant', 'Niagara', 'Ohio', 'Bradley', 'South Carolina',
#        'Fresno St', 'WI Green Bay', 'E Kentucky', 'Stony Brook',
#        'Princeton', 'SF Austin', 'G Washington', 'Tennessee St',
#        'Quinnipiac', 'Davidson', 'George Mason', 'Washington St', 'Lehigh',
#        'UC Irvine', 'Florida Intl', 'Clemson', 'Northwestern LA',
#        'Arkansas St', 'Cal Poly SLO', 'Harvard', 'Rider', 'N Dakota St',
#        'Rhode Island', 'Lafayette', 'Oakland', 'Mercer', 'Tulane',
#        "Mt St Mary's", 'Delaware', 'East Carolina', 'W Michigan', 'Tulsa',
#        'Long Island', 'Maine', 'San Francisco', 'Houston', 'Wagner',
#        'Fairfield', 'Hartford', 'Central Conn', 'Marshall', 'Auburn',
#        'UAB', 'Wright St', 'Weber St', 'Morehead St', 'Towson',
#        'UT Arlington', 'James Madison', 'Buffalo', 'West Virginia',
#        'Youngstown St', 'Ark Little Rock', 'SMU', 'W Illinois',
#        'Georgia St', 'Loyola-Chicago', 'Duquesne', 'Gardner Webb',
#        'Long Beach St', 'Missouri St', 'NC A&T', 'DePaul', 'Manhattan',
#        'Jacksonville St', 'Ga Southern', 'Santa Barbara', 'CS Northridge',
#        'Drexel', 'W Kentucky', 'Columbia', 'Savannah St', 'Bowling Green',
#        'Cleveland St', 'Boston Univ', 'Marist', 'Hawaii', 'Oral Roberts',
#        'Mississippi St', 'South Alabama', 'Montana', 'Winthrop', 'Brown',
#        'St Francis NY', 'Coastal Car', 'San Diego', 'Wofford',
#        'Texas Tech', 'UNC Asheville', 'FL Atlantic', 'UC Davis', 'Yale',
#        'Troy', 'Toledo', 'Elon', 'Sacred Heart', 'SE Louisiana',
#        'UT San Antonio', 'Norfolk St', 'McNeese St', 'NC Central',
#        'CS Fullerton', 'C Michigan', 'E Michigan', 'Ball St',
#        'CS Sacramento', 'Morgan St', 'SE Missouri St', 'North Texas',
#        'Tennessee Tech', 'Cornell', 'San Jose St', 'Southern Univ',
#        'Jacksonville', 'Holy Cross', "St Peter's", 'Loy Marymount', 'ULL',
#        'Delaware St', 'Army', 'Old Dominion', 'Montana St',
#        'Charleston So', 'Colgate', 'UNC Wilmington', 'Hampton', 'Idaho',
#        'South Dakota', 'Stetson', 'Lipscomb', 'ETSU', 'E Illinois',
#        'CS Bakersfield', 'Samford', 'Pepperdine', 'Sam Houston St',
#        'WI Milwaukee', 'Edwardsville', 'Texas St', 'High Point',
#        'SC Upstate', 'William & Mary', 'IPFW', 'American Univ',
#        'N Kentucky', 'Campbell', 'Penn', 'Liberty', 'Portland',
#        'Bethune-Cookman', 'Monmouth NJ', 'Northern Arizona',
#        'TX Pan American', 'Miami OH', 'Appalachian St', 'Hofstra',
#        'W Carolina', 'Fordham', 'TN Martin', 'Chattanooga',
#        'North Florida', 'North Dakota', 'TX Southern', 'NJIT', 'Siena',
#        'Nicholls St', 'Utah Valley', 'Radford', 'Navy', 'Cent Arkansas',
#        'E Washington', 'Southern Utah', 'Ark Pine Bluff', 'Seattle',
#        'F Dickinson', 'Dartmouth', 'N Colorado', 'VMI', 'Prairie View',
#        'MD Baltimore Co', 'Alcorn St', 'Houston Bap', 'New Hampshire',
#        'NE Omaha', 'Jackson St', 'Coppin St', 'Austin Peay', 'Missouri KC',
#        'Longwood', 'St Francis PA', 'UC Riverside', 'Portland St',
#        'Alabama A&M', 'Idaho St', 'TAM C. Christi', 'N Illinois',
#        'Chicago St', 'Presbyterian', 'Citadel', 'IUPUI', 'S Carolina St',
#        'Alabama St', 'Rice', 'Furman', 'New Orleans', 'UNC Greensboro',
#        'Kennesaw', 'ULM', 'Howard', 'Lamar', 'Florida A&M', 'MS Valley St',
#        'Binghamton', 'MD E Shore', 'Grambling'],
#       dtype='|S32'), array(['0.00965902295848', '0.00853710628128', '0.00849660534383',
#        '0.00833384108621', '0.00822350047232', '0.00814866336569',
#        '0.00789347309548', '0.00777717857129', '0.00762075812461',
#        '0.00758526012814', '0.00751266767734', '0.00739898060778',
#        '0.00739163284674', '0.00687920684685', '0.00675103226047',
#        '0.0066727230993', '0.00667238860905', '0.00656161107928',
#        '0.00655641881536', '0.00654670354456', '0.00639372931373',
#        '0.0063458585573', '0.00633859153301', '0.0063263003061',
#        '0.00630623615762', '0.00610792105597', '0.00606357922351',
#        '0.00601744378101', '0.00591092771676', '0.00589967998832',
#        '0.0058381599161', '0.00583685679185', '0.00577144772091',
#        '0.00574228821776', '0.00571039651976', '0.00542780118274',
#        '0.00540606251451', '0.00529525521113', '0.00517365393526',
#        '0.00517360013317', '0.00509269454742', '0.00508761579657',
#        '0.00506618156988', '0.00504281999799', '0.00497718727402',
#        '0.00496066991223', '0.00493394754738', '0.00491887646162',
#        '0.00491174382254', '0.00490923810328', '0.00477284046026',
#        '0.00475768157035', '0.00464624703789', '0.00461409066089',
#        '0.00454841217449', '0.00452908616856', '0.00441561246959',
